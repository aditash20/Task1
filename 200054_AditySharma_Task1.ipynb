# %% [markdown]
# ### Your task is to explain the functioning of each line in the following notebook an example is given

# %%
import tensorflow as tf  #this is used to import tensorflow for model creation and updating
import pandas as pd
import numpy as np
#tensorflow is a python library developed by google for carrying out deep learning, machine learning and neural network algorithms. It is called tensorflow beacuse multi-dimensional array are called tensors and it takes tensors as input flows them through set of algorithms and outputs the result.

# %%
import keras 
#keras is an API used as interface for heavy backend libraries such as tensorflow, CNTK and theano.

# %%
import glob
#glob is a python library used to read multiple files. It reads files and if * is at the end it reads the files having one or more charater in common. If ? then it reads files having only one element in common.

# %%
train_files=glob.glob('C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy/*')
#reading files using glob.

# %%
train_files 
#printing files.
# Out:
# ['C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\100080576_f52e8ee070_n.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10140303196_b88d3d6cec.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10172379554_b296050f82_n.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10172567486_2748826a8b.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10172636503_21bededa75_n.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\102841525_bd6628ae3c.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10300722094_28fa978807_n.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\1031799732_e7f4008c03.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10391248763_1d16681106_n.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10437754174_22ec990b77_m.jpg',
#  'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\10437770546_8bb6f7bdd3_m.jpg',
# ...

# %%
train_files[0]
# first element of array (train_files)
# Out:
# 'C:/Users/adish/Desktop/task1/archive (2)/flowers/daisy\\100080576_f52e8ee070_n.jpg'

# %%
import matplotlib.pyplot as plt
from PIL import Image
#from Python Import library import Image. Image helps in displaying image in python.

# %%
img1=Image.open(train_files[56])
#assigning a variable to the first image.

# %%
img1
#printing the first image.
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
img1_array=np.array(img1)
#making the array for the first image. Arrays for image are made by studying pixels for image which can't be seen by naked eyes.

# %%
print( img1_array.shape)
print(img1_array)
#printing array of image and it's shape.
# Out:
# (375, 500, 3)
# [[[121 101  42]
#   [125 105  44]
#   [130 111  45]
#   ...
#   [201 154 148]
#   [202 153 148]
#   [191 142 135]]
#
#  [[115  95  36]
#   [119  99  36]
#   [122 103  35]
#   ...
#   [199 150 145]
#   [190 140 133]
#   [172 119 111]]
#
#  [[113  93  32]
#   [115  95  32]
#   [117  98  30]
#   ...
#   [184 134 127]
#   [166 109 102]
#   [141  82  74]]
#
#  ...
#
#  [[ 27  18  13]
#   [ 27  18  13]
#   [ 29  18  12]
#   ...
#   [  3   1   4]
#   [  3   1   4]
#   [  2   0   3]]
#
#  [[ 24  17  11]
#   [ 26  17  12]
#   [ 27  16  12]
#   ...
#   [  2   0   3]
#   [  2   0   3]
#   [  2   0   3]]
#
#  [[ 24  17  11]
#   [ 24  17  11]
#   [ 26  17  12]
#   ...
#   [  2   0   3]
#   [  2   0   3]
#   [  2   0   3]]]
